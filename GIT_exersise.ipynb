# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/chendaniely/pandas_for_everyone/refs/heads/master/data/gapminder.tsv', sep='\t')

# %%
df.to_csv('data.csv')

# %%
cd /content/Seminars_Med/
# Out:
# /content/Seminars_Med

# %%
# !pwd
# Out:
# /content/Seminars_Med/Seminars_Med

# %%
# !git config --global user.name 'alexey.litovchenko'
# !git config --global user.email 'algaritmno822@gmail.com'

# %%
# !git config user.name
# Out:
# alexey.litovchenko

# %%
password = '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'
username = 'AlexeyTri'
repo = 'Seminars_Med'

# %%
# !git clone https://{password}@github.com/{username}/{repo}
# Out:
# Cloning into 'Seminars_Med'...
# remote: Enumerating objects: 19, done.
# remote: Counting objects: 100% (19/19), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 19 (delta 3), reused 3 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (19/19), 232.79 KiB | 5.29 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
cd /content/Seminars_Med/Seminars_Med/
# Out:
# /content/Seminars_Med/Seminars_Med

# %%
# !ls
# Out:
# data  data.csv	README.md  sem_  sem1

# %%
# !pwd
# Out:
# /content/Seminars_Med/Seminars_Med

# %%
# !git remote -v
# Out:
# origin	https://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@github.com/AlexeyTri/Seminars_Med (fetch)
# origin	https://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@github.com/AlexeyTri/Seminars_Med (push)

# %%
# !mkdir data

# %%
# !mv /content/Seminars_Med/Seminars_Med/data.csv /content/Seminars_Med/Seminars_Med/data/data.csv

# %%
# !rm -fr sem1 sem_

# %%
# !mv /content/drive/MyDrive/Seminar1_MED.ipynb /content/Seminars_Med/Seminars_Med/Seminar1_MED.ipynb

# %%
# !mv /content/drive/MyDrive/Seminar2_PyTorchExersise.ipynb /content/Seminars_Med/Seminars_Med/Seminar2_PyTorchExersise.ipynb

# %%
# !mv /content/drive/MyDrive/Seminar3_Pandas.ipynb /content/Seminars_Med/Seminars_Med/Seminar3_Pandas.ipynb

# %%
# !mv /content/drive/MyDrive/Seminar3_Pandas.ipynb /content/Seminars_Med/Seminars_Med/Seminar3_Pandas.ipynb

# %%
# !git add data.csv

# %%
# !git commit -m "add dataset"
# Out:
# [main ae5bb24] add dataset
#  1 file changed, 1705 insertions(+)
#  create mode 100644 data.csv

# %%
# !mv data.csv Seminars_Med/data.csv

# %%
# !git remote
# Out:
# origin

# %%
# !git push --set-upstream origin main
# Out:
# Enumerating objects: 4, done.
# Counting objects: 100% (4/4), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (3/3), done.
# Writing objects: 100% (3/3), 33.75 KiB | 5.62 MiB/s, done.
# Total 3 (delta 0), reused 0 (delta 0), pack-reused 0
# To https://github.com/AlexeyTri/Seminars_Med
#    60d767a..ae5bb24  main -> main
# Branch 'main' set up to track remote branch 'main' from 'origin'.
